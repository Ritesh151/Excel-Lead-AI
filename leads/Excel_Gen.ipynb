# %%
import pandas as pd 

print("Pandas version:", pd.__version__)
print("Pandas library is imported successfully...!")
# Out:
# Pandas version: 3.0.3
# Pandas library is imported successfully...!

# %%
Data = {
    "Name": [
        "Het Soni",
    ],
    "Mobile Number": [
        9327983260
    ]
}

print("Data has been created")

Data = pd.DataFrame(Data)
display(Data)
# Out:
# Data has been created
#        Name  Mobile Number
# 0  Het Soni     9327983260

# %%
Export_Data = Data.to_excel("leads.xlsx", index=False)

print("Data Exported to Excel successfully...!")
# Out:
# Data Exported to Excel successfully...!

# %%
# Check the Data
Check_Data = pd.read_excel(
    "./leads.xlsx"
    )

display(Check_Data)
# Out:
#        Name  Mobile Number
# 0  Het Soni     9327983260

# %%
# All Good...!
